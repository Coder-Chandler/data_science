# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
df1 = pd.read_csv('/Users/chandler/Desktop/test_data/work/movie_metadata.csv')

# %%
df1.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
df2 = df1[['movie_title','imdb_score','actor_1_name',
           'actor_2_name','director_name','language',
           'country','content_rating','title_year',
           'num_voted_users','movie_facebook_likes']][df1['title_year']>2000].sort_values('imdb_score',ascending=False)

# %%
df2
# Out:
#                                             movie_title  imdb_score  \
# 4409                              Kickboxer: Vengeance          9.1
# 66                                     The Dark Knight          9.0
# 339      The Lord of the Rings: The Return of the King          8.9
# 97                                           Inception          8.8
# 270   The Lord of the Rings: The Fellowship of the R...         8.8
# 4468                            Queen of the Mountains          8.7
# 4372                       A Beginner's Guide to Snuff          8.7
# 4029                                       City of God          8.7
# 4924                                    Butterfly Girl          8.7
# 340              The Lord of the Rings: The Two Towers          8.7
# 2373                                     Spirited Away          8.6
# 3816                                   Running Forever          8.6
# 96                                        Interstellar          8.6
# ...

# %%
df2.to_csv('/Users/chandler/Desktop/movie.csv', index=False)
