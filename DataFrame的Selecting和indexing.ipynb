# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
# !pwd
# Out:
# /Users/chandler

# %%
# !ls /Users/chandler/Documents/Data
# Out:
# 2000_shenfenzhen.rar
# DataAnalyst-2.csv
# README.md
# WEB_log
# realm-nem2017-traces
# spider_data
# test_data
# titanic
# 物流数据
# 股票数据
# 国家名称.xlsx
# 上海租房分析
# 数据分析案例
# 数据分析数据.docx
# 牛奶可乐经济学.pdf
# 应用随机过程概率模型导论(第10版).pdf

# %%
impd = pd.read_csv('/Users/chandler/Documents/Data/DataAnalyst-2.csv',encoding="gb2312")

# %%
impd.shape
# Out:
# (5032, 41)

# %%
impd.head()
# Out:
#   city    companyFullName  companyId companyLabelList_1 companyLabelList_2  \
# 0   上海     纽海信息技术(上海)有限公司       8581               技能培训               节日礼物
# 1   上海   上海点荣金融信息服务有限责任公司      23177               节日礼物               带薪年假
# 2   上海     上海晶樵网络信息技术有限公司      57561               技能培训               绩效奖金
# 3   上海  杭州数云信息技术有限公司上海分公司       7502               绩效奖金               股票期权
# 4   上海     上海银基富力信息技术有限公司     130876               年底双薪               通讯津贴
#
#   companyLabelList_3 companyLabelList_4 companyShortName companySize  \
# 0               带薪年假               岗位晋升              1号店     2000人以上
# 1               岗位晋升               扁平管理              点融网   500-2000人
# 2               岗位晋升               管理规范              SPD     50-150人
# 3               五险一金               通讯津贴               数云    150-500人
# 4               定期体检               绩效奖金             银基富力      15-50人
#
#   businessZones_1       ...       positionLables_9 positionLables_10  \
# ...

# %%
impd.tail(5)
# Out:
#      city  companyFullName  companyId companyLabelList_1 companyLabelList_2  \
# 5027   天津    广州市卓为信息技术有限公司      94608               带薪年假               绩效奖金
# 5028   天津     广州安正软件股份有限公司      22182               技能培训               年度旅游
# 5029   天津  天津闯先生网络科技有限责任公司      15955               绩效奖金               五险一金
# 5030   天津   天津五八到家生活服务有限公司      81280               绩效奖金                领导好
# 5031   天津  天津市神州商龙科技股份有限公司      31444               技能培训               年底双薪
#
#      companyLabelList_3 companyLabelList_4 companyShortName companySize  \
# 5027                帅哥多                美女多             广州卓为     50-150人
# 5028               岗位晋升               扁平管理             安正软件    150-500人
# 5029               通讯津贴               年度旅游     闯先生Mr.Chuang      15-50人
# 5030                美女多                帅哥多             58到家     2000人以上
# 5031               节日礼物                采暖费             神州商龙    150-500人
#
#      businessZones_1       ...       positionLables_9 positionLables_10  \
# ...

# %%
sub_df = impd[['city','companyFullName','min_salary','max_salary','workYear','positionName','industryField']][100:110]

# %%
sub_df
# Out:
#     city   companyFullName  min_salary max_salary workYear  \
# 100   上海      上海艾匀信息科技有限公司          15         25     1-3年
# 101   上海  善林（上海）金融信息服务有限公司           4          6     1-3年
# 102   上海    新蛋信息技术（中国）有限公司          15         20     1-3年
# 103   上海     上海方付通商务服务有限公司          15         25     1-3年
# 104   上海    陕西西普数据通信股份有限公司          20         25     1-3年
# 105   上海      上海好居信息科技有限公司          20         30     1-3年
# 106   上海      上海星艾网络科技有限公司           7         10     1-3年
# 107   上海       上海萨图西网络有限公司          10         20     1-3年
# 108   上海      上海触乐信息科技有限公司          15         30     1-3年
# 109   上海   拉扎斯网络科技（上海）有限公司          10         18     1-3年
#
#               positionName industryField
# 100                  数据工程师    移动互联网,数据服务
# 101                   数据专员            金融
# 102               大数据开发工程师          电子商务
# 103               大数据开发工程师      移动互联网,金融
# 104        大数据算法工程师（模型和分析）    移动互联网,电子商务
# 105               大数据研发工程师     移动互联网,O2O
# ...

# %%
sub_df.iloc[0:10,0:6]
# Out:
#     city   companyFullName  min_salary max_salary workYear  \
# 100   上海      上海艾匀信息科技有限公司          15         25     1-3年
# 101   上海  善林（上海）金融信息服务有限公司           4          6     1-3年
# 102   上海    新蛋信息技术（中国）有限公司          15         20     1-3年
# 103   上海     上海方付通商务服务有限公司          15         25     1-3年
# 104   上海    陕西西普数据通信股份有限公司          20         25     1-3年
# 105   上海      上海好居信息科技有限公司          20         30     1-3年
# 106   上海      上海星艾网络科技有限公司           7         10     1-3年
# 107   上海       上海萨图西网络有限公司          10         20     1-3年
# 108   上海      上海触乐信息科技有限公司          15         30     1-3年
# 109   上海   拉扎斯网络科技（上海）有限公司          10         18     1-3年
#
#               positionName
# 100                  数据工程师
# 101                   数据专员
# 102               大数据开发工程师
# 103               大数据开发工程师
# 104        大数据算法工程师（模型和分析）
# 105               大数据研发工程师
# 106                 数据分析主管
# 107  数据工程师 / Data Engineer
# 108                 大数据工程师
# 109               数据/业务分析师

# %%
sub_df.loc[100:105,'city':'workYear']
# Out:
#     city   companyFullName  min_salary max_salary workYear
# 100   上海      上海艾匀信息科技有限公司          15         25     1-3年
# 101   上海  善林（上海）金融信息服务有限公司           4          6     1-3年
# 102   上海    新蛋信息技术（中国）有限公司          15         20     1-3年
# 103   上海     上海方付通商务服务有限公司          15         25     1-3年
# 104   上海    陕西西普数据通信股份有限公司          20         25     1-3年
# 105   上海      上海好居信息科技有限公司          20         30     1-3年
